# %% [markdown]
# <a href="https://colab.research.google.com/github/alvincharles45/alvincharles45.github.io/blob/main/notebooks/starter_publishing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
restart = True
epoch_to_pickup = 0

# %%
# Import libraries

from tensorflow.keras.layers import StringLookup
import numpy as np
import os
import time
import random
import contextlib
import io
import re
import string
import gc  # Import the garbage collector module

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.layers import TextVectorization

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
path = ''

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# path = '/content/drive/My Drive/M6_Fall2023e/'

# %% [markdown]
# ## Functions for downloading text

# %%
def preprocess_text(text):

    text = text.replace("Project Gutenberg", "")
    text = text.replace("Gutenberg", "")

    # Remove carriage returns
    text = text.replace("\r", "")

    # fix quotes
    text = text.replace("“", "\"")
    text = text.replace("”", "\"")

    # Replace any capital letter at the start of a word with ^ followed by the lowercase letter
    text = re.sub(r"(?<![a-zA-Z])([A-Z])", lambda match: f"^{match.group(0).lower()}", text)

    # Replace all other capital letters with lowercase
    text = re.sub(r"([A-Z])", lambda match: f"{match.group(0).lower()}", text)

    # Remove duplicate whitespace
    text = re.sub(r"\s+", " ", text)
    text = re.sub(r"\n+", "\n", text)
    text = re.sub(r"\t+", "\t", text)

    # Replace whitespace characters with special words
    text = re.sub(r"(\t)", r" zztabzz ", text)
    text = re.sub(r"(\n)", r" zznewlinezz ", text)
    text = re.sub(r"(\s)", r" zzspacezz ", text)

    # Split before and after punctuation
    for punctuation in string.punctuation:
        text = text.replace(punctuation, f" {punctuation} ")

    return text

# %%
def postprocess_text(text):

    # Replace special words with whitespace characters
    text = text.replace("zztabzz", "\t")
    text = text.replace("zznewlinezz", "\n")
    text = text.replace("zzspacezz", " ")

    # Remake capital letters at beginning of words
    text = re.sub(r"\^([a-z])", lambda match: f"{match.group(1).upper()}", text)

    text = text.replace("^", "")

    return text

# %%
# def getMyText():
#   path_to_file = tf.keras.utils.get_file('austen.txt', 'https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/austen/austen.txt')

#   text = open(path_to_file, 'rb').read().decode(encoding='utf-8')

#   # path_to_file = tf.keras.utils.get_file('903-0.txt', 'https://www.gutenberg.org/files/903/903-0.txt')
#   # author_text += open(path_to_file, 'rb').read().decode(encoding='utf-8')[2999:-19194]
#   # tf.io.gfile.remove(path_to_file)

#   return preprocess_text(text)

import os
import tensorflow as tf

def getMyText():
    file_name = 'C&P.txt'
    file_url = 'https://www.gutenberg.org/cache/epub/2554/pg2554.txt'
    local_dir = 'saved_files'  # Directory to save the file
    local_path = os.path.join(local_dir, file_name)

    try:
        # Ensure the directory exists
        if not os.path.exists(local_dir):
            os.makedirs(local_dir)

        # Check if the file exists locally
        if os.path.exists(local_path):
            print(f"File '{file_name}' found locally. Using it.")
        else:
            print(f"File '{file_name}' not found locally. Downloading it.")
            # Download the file
            downloaded_path = tf.keras.utils.get_file(file_name, file_url)

            # Save the downloaded file to the designated local directory
            with open(downloaded_path, 'rb') as source_file:
                with open(local_path, 'wb') as dest_file:
                    dest_file.write(source_file.read())

        # Read the file's contents
        with open(local_path, 'rb') as file:
            text = file.read().decode(encoding='utf-8')

        return preprocess_text(text)

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
getMyText()
# Out:
# File 'C&P.txt' not found locally. Downloading it.
# Downloading data from https://www.gutenberg.org/cache/epub/2554/pg2554.txt
# 1201764/1201764 ━━━━━━━━━━━━━━━━━━━━ 1s 1us/step
# '\ufeff ^ the zzspacezz ebook zzspacezz of zzspacezz  ^ crime zzspacezz and zzspacezz  ^ punishment zzspacezz  ^ this zzspacezz ebook zzspacezz is zzspacezz for zzspacezz the zzspacezz use zzspacezz of zzspacezz anyone zzspacezz anywhere zzspacezz in zzspacezz the zzspacezz  ^ united zzspacezz  ^ states zzspacezz and zzspacezz most zzspacezz other zzspacezz parts zzspacezz of zzspacezz the zzspacezz world zzspacezz at zzspacezz no zzspacezz cost zzspacezz and zzspacezz with zzspacezz almost zzspacezz no zzspacezz restrictions zzspacezz whatsoever .  zzspacezz  ^ you zzspacezz may zzspacezz copy zzspacezz it ,  zzspacezz give zzspacezz it zzspacezz away zzspacezz or zzspacezz re - use zzspacezz it zzspacezz under zzspacezz the zzspacezz terms zzspacezz of zzspacezz the zzspacezz  ^ license zzspacezz included zzspacezz with zzspacezz this zzspacezz ebook zzspacezz or zzspacezz online zzspacezz at zzspacezz www . gutenberg . org .  zzspacezz  ^ if zzspacezz you zzspacezz are zzspacezz not zzspacezz located zzspacezz in zzspacezz the zzspacezz  ^ united zzspacezz  ^ states ,  zzspacezz you zzspacezz will zzspacezz have zzspacezz to zzspacezz check zzspacezz the zzspacezz laws zzspacezz of zzspacezz the zzspacezz country zzspacezz where zzspacezz you zzspacezz are zzspacezz located zzspacezz before zzspacezz using zzspacezz this zzspacezz ebook .  zzspacezz  ^ title :  zzspacezz  ^ crime zzspacezz and zzspacezz  ^ punishment zzspacezz  ^ author :  zzspacezz  ^ fyodor zzspacezz  ^ dostoyevsky zzspacezz  ^ translator :  zzspacezz  ^ constance zzspacezz  ^ garnett zzspacezz  ^ release zzspacezz date :  zzspacezz  ^ march zzspacezz 28 ,  zzspacezz 2006 zzspacezz  [ ebook zzspacezz  # 2554 ]  zzspacezz  ^ most zzspacezz recently zzspacezz updated :  zzspacezz  ^ june zzspacezz 10 ,  zzspacezz 2025 zzspacezz  ^ language :  zzspacezz  ^ english zzspacezz  ^ credits :  zzspacezz  ^ john zzspacezz  ^ bickers ,  zzspacezz  ^ dagny zzspacezz and zzspacezz  ^ david zzspacezz  ^ widger zzspacezz  *  *  *  zzspacezz  ^ start zzspacezz  ^ of zzspacezz  ^ the zzspacezz  ^ project zzspacezz  ^ gutenberg zzspacezz  ^ ebook zzspacezz  ^ crime zzspacezz  ^ and zzspacezz  ^ punishment zzspacezz  *  *  *  zzspacezz  ^ crime zzspacezz  ^ and zzspacezz  ^ punishment zzspacezz  ^ by zzspacezz  ^ fyodor zzspacezz  ^ dostoevsky zzspacezz  ^ translated zzspacezz  ^ by zzspacezz  ^ constance zzspacezz  ^ garnett zzspacezz  ^ translator’ ^ s zzspacezz  ^ preface zzspacezz  ^ a zzspacezz few zzspacezz words zzspacezz about zzspacezz  ^ dostoevsky zzspacezz himself zzspacezz may zzspacezz help zzspacezz the zzspacezz  ^ english zzspacezz reader zzspacezz to zzspacezz understand zzspacezz his zzspacezz work .  zzspacezz  ^ dostoevsky zzspacezz was zzspacezz the zzspacezz son zzspacezz of zzspacezz a zzspacezz doctor .  zzspacezz  ^ his zzspacezz parents zzspacezz were zzspacezz very zzspacezz hard - working zzspacezz and zzspacezz deeply zzspacezz religious zzspacezz people ,  zzspacezz but zzspacezz so zzspacezz poor zzspacezz that zzspacezz they zzspacezz lived zzspacezz with zzspacezz their zzspacezz five zzspacezz children zzspacezz in zzspacezz only zzspacezz two zzspacezz rooms .  zzspacezz  ^ the zzspacezz father zzspacezz and zzspacezz mother zzspacezz spent zzspacezz their zzspacezz evenings zzspacezz in zzspacezz reading zzspacezz aloud zzspacezz to zzspacezz their zzspacezz children ,  zzspacezz generally zzspacezz from zzspacezz books zzspacezz of zzspacezz a zzspacezz serious zzspacezz character .  zzspacezz  ^ though zzspacezz always zzspacezz sickly zzspacezz and zzspacezz delicate zzspacezz  ^ dostoevsky zzspacezz came zzspacezz out zzspacezz third zzspacezz in zzspacezz the zzspacezz final zzspacezz examination zzspacezz of zzspacezz the zzspacezz  ^ petersburg zzspacezz school zzspacezz of zzspacezz  ^ engineering .  zzspacezz  ^ there zzspacezz he zzspacezz had zzspacezz already zzspacezz begun zzspacezz his zzspacezz first zzspacezz work ,  zzs ...

# %%
def getRandomText(numbooks = 1, verbose=False):
  download_log = io.StringIO()
  text_random = ''
  for b in range(numbooks):
    foundbook = False
    while(foundbook == False):
      booknum = random.randint(100,60000)
      if verbose:
        print('Trying Book #: ',booknum)
      if random.random() > 0.5:
        url = 'https://www.gutenberg.org/files/' + str(booknum) + '/' + str(booknum) + '-0.txt'
        filename_temp = str(booknum) + '-0.txt'
      else:
        url = 'https://www.gutenberg.org/cache/epub/' + str(booknum) + '/pg' + str(booknum) + '.txt'
        filename_temp = 'pg' + str(booknum) + '.txt'
      if verbose:
        print('Trying: ', url)
      try:
        if verbose:
          path_to_file_temp = tf.keras.utils.get_file(filename_temp, url)
        else:
          with contextlib.redirect_stdout(download_log):
            path_to_file_temp = tf.keras.utils.get_file(filename_temp, url)
        temptext = open(path_to_file_temp, 'rb').read().decode(encoding='utf-8')
        tf.io.gfile.remove(path_to_file_temp)
        if (temptext.find('Language: English') >= 0):
          offset = random.randint(-20,20)
          header = 2000
          total_length = 200000
          chopoffend = 10000
          if len(temptext) > (header+total_length+offset+chopoffend):
            foundbook = True
            text_random += temptext[header+offset:header+total_length+offset]
            #print("Yes: " + str(booknum))
            if verbose:
              print('New size of dataset: ', len(text_random))
          elif len(temptext) > (header+12000):
            foundbook = True
            text_random += temptext[header:-chopoffend]
            #print("Yes (smaller): " + str(booknum))
            if verbose:
              print('New size of dataset: ', len(text_random))
          else:
            if verbose:
              print('Not long enough. Trying again...')
            #print("No: " + str(booknum) + " too short")
        else:
          if verbose:
            print('Not English. Trying again...')
          #print("No: " + str(booknum) + " not English")
        del temptext
      except:
        if verbose:
          print('Not valid file. Trying again...')
        #print("No: " + str(booknum) + " not valid")
        foundbook = False
    if verbose:
      print("Found " + str(b+1) + " books so far...")
  del download_log
  #text_random = "".join(c for c in text_random if c in vocab)
  #all_ids_random = ids_from_chars(tf.strings.unicode_split(text_random, 'UTF-8'))
  #ids_dataset_random = tf.data.Dataset.from_tensor_slices(all_ids_random)
  #sequences_random = ids_dataset_random.batch(seq_length+1, drop_remainder=True)
  #dataset_random = sequences_random.map(split_input_target)
  #dataset_random = (dataset_random.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True).prefetch(tf.data.experimental.AUTOTUNE))
  #return dataset_random
  return preprocess_text(text_random)

# %%
if restart:
  vocab_text = getMyText()
# Out:
# File 'C&P.txt' found locally. Using it.

# %% [markdown]
# Make vocabulary (Adapted from TensorFlow word embedding tutorial)
#
# ---

# %%
# Vocabulary size and number of words in a sequence.
vocab_size = 8192
sequence_length = 128

# %%
if restart:
  # Use the text vectorization layer to normalize, split, and map strings to
  # integers. Note that the layer uses the custom standardization defined above.
  # Set maximum_sequence length as all samples are not of the same length.
  vectorize_layer = TextVectorization(
      standardize='lower',
      split='whitespace',
      max_tokens=vocab_size,
      output_mode='int',
      #output_sequence_length=sequence_length
      )

# %%
if restart:
  # Make a text-only dataset (no labels) and call adapt to build the vocabulary.
  vectorize_layer.adapt([vocab_text])

# %%
if restart:
  vocabulary = vectorize_layer.get_vocabulary()

# %% [markdown]
# Save Vocabulary

# %%
if restart:
  with open(path + "vocabulary.txt", "w") as file:
    for word in vocabulary:
        file.write(word + "\n")

# %% [markdown]
# Load Saved Vocabulary

# %%
if restart == False:
  with open(path + "vocabulary.txt", "r") as file:
      vocabulary = [word.strip() for word in file.readlines()]
      vocabulary = vocabulary

  vectorize_layer = TextVectorization(
      vocabulary=vocabulary,
      standardize='lower',
      split='whitespace',
      max_tokens=vocab_size,
      output_mode='int',
      #output_sequence_length=sequence_length
      )

# %%
print(vocabulary[:20])
print(vocabulary[-20:])
# Out:
# ['', '[UNK]', np.str_('zzspacezz'), np.str_('^'), np.str_(','), np.str_('.'), np.str_('the'), np.str_('"'), np.str_('and'), np.str_('to'), np.str_('he'), np.str_('a'), np.str_('i'), np.str_('of'), np.str_('you'), np.str_('in'), np.str_('it'), np.str_('that'), np.str_('was'), np.str_('!')]
# [np.str_('irrevocable'), np.str_('irreproachable'), np.str_('irregularity'), np.str_('irrational'), np.str_('irksome'), np.str_('iou'), np.str_('involving'), np.str_('involved'), np.str_('involuntary'), np.str_('investigators'), np.str_('investigating'), np.str_('investigated'), np.str_('investigate'), np.str_('invents'), np.str_('invent'), np.str_('invaluable'), np.str_('invalidity'), np.str_('intrusive'), np.str_('intrude'), np.str_('introduction')]

# %% [markdown]
# Turn text into a dataset

# %%
# This function will generate our sequence pairs:
def split_input_target(sequence):
    input_ids = sequence[:-1]
    target_ids = sequence[1:]
    return input_ids, target_ids

# This function will create the dataset
def text_to_dataset(text):
  all_ids = vectorize_layer(text)
  ids_dataset = tf.data.Dataset.from_tensor_slices(all_ids)
  del all_ids
  sequences = ids_dataset.batch(sequence_length+1, drop_remainder=True)
  del ids_dataset

  # Call the function for every sequence in our list to create a new dataset
  # of input->target pairs
  dataset = sequences.map(split_input_target)
  del sequences

  # shuffle


  return dataset

# %% [markdown]
# Test on vocab text

# %%
if restart:
  vocab_ds = text_to_dataset(vocab_text)

# %%
def text_from_ids(ids):
  text = ''.join([vocabulary[index] for index in ids])
  return postprocess_text(text)

vocabulary_adjusted = vocabulary
vocabulary_adjusted[0] = '[UNK]'
vocabulary_adjusted[1] = ''

words_from_ids = tf.keras.layers.StringLookup(vocabulary=vocabulary_adjusted, invert=True)

# %%
if restart:
  for input_example, target_example in vocab_ds.take(1):
    print("Input: ")
    print(input_example)
    print(text_from_ids(input_example))
    print(words_from_ids(input_example))
    print("Target: ")
    print(target_example)
    print(text_from_ids(target_example))
# Out:
# Input:
# tf.Tensor(
# [6100    3    6    2 1508    2   13    2    3  462    2    8    2    3
#  2108    2    3   46    2 1508    2   33    2   28    2    6    2  437
#     2   13    2  370    2 2237    2   15    2    6    2    3 1163    2
#     3 1032    2    8    2  221    2  157    2 2580    2   13    2    6
#     2  575    2   23    2   50    2 1868    2    8    2   27    2  146
#     2   50    2 5008    2 3791    5    2    3   14    2  153    2 1421
#     2   16    4    2  226    2   16    2  128    2   69    2 3369   21
#   437    2   16    2  276    2    6    2  731    2   13    2    6    2
#     3 1044    2 4229    2   27    2   46    2 1508    2   69    2 3435
#     2   23], shape=(128,), dtype=int64)
# ﻿The ebook of Crime and Punishment This ebook is for the use of anyone anywhere in the United States and most other parts of the world at no cost and with almost no restrictions whatsoever. You may copy it, give it away or re-use it under the terms of the License included with this ebook or online at
# tf.Tensor(
# [b'\xef\xbb\xbf' b'^' b'the' b'zzspacezz' b'ebook' b'zzspacezz' b'of'
#  b'zzspacezz' b'^' b'crime' b'zzspacezz' b'and' b'zzspacezz' b'^'
#  b'punishment' b'zzspacezz' b'^' b'this' b'zzspacezz' b'ebook'
#  b'zzspacezz' b'is' b'zzspacezz' b'for' b'zzspacezz' b'the' b'zzspacezz'
#  b'use' b'zzspacezz' b'of' b'zzspacezz' b'anyone' b'zzspacezz' b'anywhere'
#  b'zzspacezz' b'in' b'zzspacezz' b'the' b'zzspacezz' b'^' b'united'
#  b'zzspacezz' b'^' b'states' b'zzspacezz' b'and' b'zzspacezz' b'most'
#  b'zzspacezz' b'other' b'zzspacezz' b'parts' b'zzspacezz' b'of'
#  b'zzspacezz' b'the' b'zzspacezz' b'world' b'zzspacezz' b'at' b'zzspacezz'
#  b'no' b'zzspacezz' b'cost' b'zzspacezz' b'and' b'zzspacezz' b'with'
#  b'zzspacezz' b'almost' b'zzspacezz' b'no' b'zzspacezz' b'restrictions'
#  b'zzspacezz' b'whatsoever' b'.' b'zzspacezz' b'^' b'you' b'zzspacezz'
#  b'may' b'zzspacezz' b'copy' b'zzspacezz' b'it' b',' b'zzspacezz' b'give'
#  b'zzspacezz' b'it' b'zzspacezz' b'away' b'zzspacezz' b'or' b'zzspacezz'
#  b're' b'-' b'use' b'zzspacezz' b'it' b'zzspacezz' b'under' b'zzspacezz'
#  b'the' b'zzspacezz' b'terms' b'zzspacezz' b'of' b'zzspacezz' b'the'
#  b'zzspacezz' b'^' b'license' b'zzspacezz' b'included' b'zzspacezz'
#  b'with' b'zzspacezz' b'this' b'zzspacezz' b'ebook' b'zzspacezz' b'or'
#  b'zzspacezz' b'online' b'zzspacezz' b'at'], shape=(128,), dtype=string)
# Target:
# tf.Tensor(
# [   3    6    2 1508    2   13    2    3  462    2    8    2    3 2108
#     2    3   46    2 1508    2   33    2   28    2    6    2  437    2
#    13    2  370    2 2237    2   15    2    6    2    3 1163    2    3
#  1032    2    8    2  221    2  157    2 2580    2   13    2    6    2
#   575    2   23    2   50    2 1868    2    8    2   27    2  146    2
#    50    2 5008    2 3791    5    2    3   14    2  153    2 1421    2
#    16    4    2  226    2   16    2  128    2   69    2 3369   21  437
#     2   16    2  276    2    6    2  731    2   13    2    6    2    3
#  1044    2 4229    2   27    2   46    2 1508    2   69    2 3435    2
#    23    2], shape=(128,), dtype=int64)
# The ebook of Crime and Punishment This ebook is for the use of anyone anywhere in the United States and most other parts of the world at no cost and with almost no restrictions whatsoever. You may copy it, give it away or re-use it under the terms of the License included with this ebook or online at

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 10000

def setup_dataset(dataset):
  dataset = (
    dataset
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE, drop_remainder=True)
    .prefetch(tf.data.experimental.AUTOTUNE))
  return dataset

# %%
if restart:
  vocab_ds = setup_dataset(vocab_ds)

# %% [markdown]
# ## III. Build the model
#
# Next, we'll build our model. Up until this point, you've been using the Keras symbolic, or imperative API for creating your models. Doing something like:
#
#     model = tf.keras.models.Sequentla()
#     model.add(tf.keras.layers.Dense(80, activation='relu))
#     etc...
#
# However, tensorflow has another way to build models called the Functional API, which gives us a lot more control over what happens inside the model. You can read more about [the differences and when to use each here](https://blog.tensorflow.org/2019/01/what-are-symbolic-and-imperative-apis.html).
#
# We'll use the functional API for our RNN in this example. This will involve defining our model as a custom subclass of `tf.keras.Model`.
#
# If you're not familiar with classes in python, you might want to review [this quick tutorial](https://www.w3schools.com/python/python_classes.asp), as well as [this one on class inheritance](https://www.w3schools.com/python/python_inheritance.asp).
#
# Using a functional model is important for our situation because we're not just training it to predict a single character for a single sequence, but as we make predictions with it, we need it to remember those predictions as use that memory as it makes new predictions.

# %%
# Create our custom model. Given a sequence of characters, this
# model's job is to predict what character should come next.
class AustenTextModel(tf.keras.Model):

  # This is our class constructor method, it will be executed when
  # we first create an instance of the class
  def __init__(self, vocab_size, embedding_dim, rnn_units):
    super().__init__()

    # Our model will have three layers:

    # 1. An embedding layer that handles the encoding of our vocabulary into
    #    a vector of values suitable for a neural network
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)

    # 2. A GRU layer that handles the "memory" aspects of our RNN. If you're
    #    wondering why we use GRU instead of LSTM, and whether LSTM is better,
    #    take a look at this article: https://datascience.stackexchange.com/questions/14581/when-to-use-gru-over-lstm
    #    then consider trying out LSTM instead (or in addition to!)
    #self.gru = tf.keras.layers.GRU(rnn_units, return_sequences=True, return_state=True)
    self.lstm1 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
    self.lstm2 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
    self.lstm3 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
    #self.lstm4 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)


    self.hidden1 = tf.keras.layers.Dense(embedding_dim*64, activation='relu')
    self.hidden2 = tf.keras.layers.Dense(embedding_dim*16, activation='relu')
    #self.hidden3 = tf.keras.layers.Dense(embedding_dim*4, activation='relu')

    # 3. Our output layer that will give us a set of probabilities for each
    #    character in our vocabulary.
    self.dense = tf.keras.layers.Dense(vocab_size)

  # This function will be executed for each epoch of our training. Here
  # we will manually feed information from one layer of our network to the
  # next.
  def call(self, inputs, states=None, return_state=False, training=False):
    x = inputs

    # 1. Feed the inputs into the embedding layer, and tell it if we are
    #    training or predicting
    x = self.embedding(x, training=training)

    # 2. If we don't have any state in memory yet, get the initial random state
    #    from our GRUI layer.
    batch_size = tf.shape(inputs)[0]

    if states is None:
      states1 = [tf.zeros([batch_size, self.lstm1.units]), tf.zeros([batch_size, self.lstm1.units])]
      states2 = [tf.zeros([batch_size, self.lstm2.units]), tf.zeros([batch_size, self.lstm2.units])]
      states3 = [tf.zeros([batch_size, self.lstm3.units]), tf.zeros([batch_size, self.lstm3.units])]
      #states4 = [tf.zeros([batch_size, self.lstm4.units]), tf.zeros([batch_size, self.lstm4.units])]
    else:
      states1 = states[0]
      states2 = states[1]
      states3 = states[2]
      #states4 = states[3]
    # 3. Now, feed the vectorized input along with the current state of memory
    #    into the gru layer.
    x, state_h_1, state_c_1 = self.lstm1(x, initial_state=states1, training=training)
    states_out_1 = [state_h_1,state_c_1]

    x, state_h_2, state_c_2 = self.lstm2(x, initial_state=states2, training=training)
    states_out_2 = [state_h_2,state_c_2]

    x, state_h_3, state_c_3 = self.lstm3(x, initial_state=states3, training=training)
    states_out_3 = [state_h_3,state_c_3]

    #x, state_h_4, state_c_4 = self.lstm4(x, initial_state=states4, training=training)
    #states_out_4 = [state_h_4,state_c_4]

    states_out = [states_out_1, states_out_2, states_out_3]#, states_out_4]
    #states_out = [states_out_1, states_out_2]

    x = self.hidden1(x,training=training)
    x = self.hidden2(x,training=training)
    #x = self.hidden3(x,training=training)
    # 4. Finally, pass the results on to the dense layer
    x = self.dense(x, training=training)

    # 5. Return the results
    if return_state:
      return x, states_out
    else:
      return x

# %%
if restart:
  dataset = vocab_ds
  del vocab_text
  del vocab_ds
else:
  new_text = getRandomText(numbooks = 10)
  dataset = text_to_dataset(new_text)
  del new_text
  dataset = setup_dataset(dataset)

# %%
# Create an instance of our model
#vocab_size=len(ids_from_chars.get_vocabulary())
embedding_dim = 128
rnn_units = 512

model = AustenTextModel(vocab_size, embedding_dim, rnn_units)

# %%
# Verify the output of our model is correct by running one sample through
# This will also compile the model for us. This step will take a bit.
for input_example_batch, target_example_batch in dataset.take(1):
    example_batch_predictions = model(input_example_batch)
    print(example_batch_predictions.shape, "# (batch_size, sequence_length, vocab_size)")
# Out:
# (64, 128, 8192) # (batch_size, sequence_length, vocab_size)

# %%
# Now let's view the model summary
model.summary()
# Out:
# Model: "austen_text_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (64, 128, 128)         │     1,048,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ((64, 128, 512), (64,  │     1,312,768 │
# │                                 │ 512), (64, 512))       │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ((64, 128, 512), (64,  │     2,099,200 │
# │                                 │ 512), (64, 512))       │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ ((64, 128, 512), (64,  │     2,099,200 │
# │                                 │ 512), (64, 512))       │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (64, 128, 8192)        │     4,202,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (64, 128, 2048)        │    16,779,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (64, 128, 8192)        │    16,785,408 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,326,912 (169.09 MB)
#  Trainable params: 44,326,912 (169.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Here's the code we'll use to sample for us. It has some extra steps to apply
# the temperature to the distribution, and to make sure we don't get empty
# characters in our text. Most importantly, it will keep track of our model
# state for us.

class OneStep(tf.keras.Model):
  def __init__(self, model, vectorize_layer, vocabulary, temperature=1):
    super().__init__()
    self.temperature=temperature
    self.model = model
    self.vectorize_layer = vectorize_layer
    self.vocabulary = vocabulary
    #print("initialized")

    # Create a mask to prevent "" or "[UNK]" from being generated.
    skip_ids = StringLookup(vocabulary=list(vocabulary))(['', '[UNK]'])[:, None]
    #print(skip_ids)
    #print("3")
    sparse_mask = tf.SparseTensor(
        # Put a -inf at each bad index.
        values=[-float('inf')]*len(skip_ids),
        indices = skip_ids,
        # Match the shape to the vocabulary
        dense_shape=[len(vocabulary)])
    #print("4")
    self.prediction_mask = tf.sparse.to_dense(sparse_mask,validate_indices=False)
    #print("5")

  @tf.function
  def generate_one_step(self, inputs, states=None):
    # Convert strings to token IDs.
    #input_chars = tf.strings.unicode_split(inputs, 'UTF-8')
    input_ids = self.vectorize_layer(inputs)
    #print(input_ids)

    # Run the model.
    # predicted_logits.shape is [batch, char, next_char_logits]
    predicted_logits, states =  self.model(inputs=input_ids, states=states,
                                          return_state=True)
    del input_ids
    # Only use the last prediction.
    predicted_logits = predicted_logits[:, -1, :]
    predicted_logits = predicted_logits/self.temperature

    # Apply the prediction mask: prevent "" or "[UNK]" from being generated.
    predicted_logits = predicted_logits + self.prediction_mask

    # Sample the output logits to generate token IDs.
    predicted_ids = tf.random.categorical(predicted_logits, num_samples=1)
    del predicted_logits
    predicted_ids = tf.squeeze(predicted_ids, axis=-1)

    #print(predicted_ids[0])

    # Return the characters and model state.
    return words_from_ids(predicted_ids), states

# %%
def produce_sample(model, vectorize_layer, vocabulary, temp, epoch, prompt):
  # Create an instance of the character generator
  #print("entered")
  one_step_model = OneStep(model, vectorize_layer, vocabulary, temp)
  #print("rand one step")
  # Now, let's generate a 1000 character chapter by giving our model "Chapter 1"
  # as its starting text
  states = None
  next_char = tf.constant([preprocess_text(prompt)])
  result = [tf.constant([prompt])]

  for n in range(200):
    next_char, states = one_step_model.generate_one_step(next_char, states=states)
    #print(next_char)
    result.append(next_char)
    #print(result)

  result = tf.strings.join(result)
  #print(result)

  # Print the results formatted.
  #print('Temp: ' + str(temp) + '\n')
  print(postprocess_text(result[0].numpy().decode('utf-8')))
  #print('\n\n')
  print('Epoch: ' + str(epoch) + '\n', file=open(path + 'tree.txt', 'a'))
  print('Temp: ' + str(temp) + '\n', file=open(path + 'tree.txt', 'a'))
  print(postprocess_text(result[0].numpy().decode('utf-8')), file=open(path + 'tree.txt', 'a'))
  print('\n\n', file=open(path + 'tree.txt', 'a'))
  del states
  del next_char
  del result

# %% [markdown]
# ## IV. Train the model
#
# For our purposes, we'll be using [categorical cross entropy](https://machinelearningmastery.com/cross-entropy-for-machine-learning/) as our loss function*. Also, our model will be outputting ["logits" rather than normalized probabilities](https://stackoverflow.com/questions/41455101/what-is-the-meaning-of-the-word-logits-in-tensorflow), because we'll be doing further transformations on the output later.
#
#
# \* Note that since our model deals with integer encoding rather than one-hot encoding, we'll specifically be using [sparse categorical cross entropy](https://stats.stackexchange.com/questions/326065/cross-entropy-vs-sparse-cross-entropy-when-to-use-one-over-the-other).

# %%
# sherlock_text = getMyText()

# %%
if restart == False:
  model.load_weights(path + "lstm_gru_SH_modelweights_fall2023-random_urls.h5")

# %%
loss = tf.losses.SparseCategoricalCrossentropy(from_logits=True)
opt = tf.keras.optimizers.Adam(learning_rate=0.002)
model.compile(optimizer=opt, loss=loss)

num_epochs_total = 5
if restart:
  start_epoch = 0
else:
  start_epoch = epoch_to_pickup
for e in range(start_epoch, num_epochs_total):
  success = False
  while(success == False):
    try:
      print("epoch: ", e)
      # if e < 50:
      #   new_text = getRandomText(numbooks = 20)
      # else:
      #   new_text = sherlock_text + getRandomText(numbooks = (num_epochs_total - e)//10)
      new_text = getMyText()
      dataset = text_to_dataset(new_text)
      del new_text
      dataset = setup_dataset(dataset)
      #opt = tf.keras.optimizers.Adam(learning_rate=0.002*(0.97**e))
      #model.compile(optimizer=opt, loss=loss)
      model.optimizer.learning_rate.assign(0.002*(0.99**e))
      model.fit(dataset, epochs=1, verbose=1)
      print("finished training...")
      del dataset
      #print("saving weights...")
      #model.save_weights(path + "lstm_gru_SH_modelweights_fall2023-random_urls.h5")
      #print("weights saved...")
      for temp in [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]:
        produce_sample(model,vectorize_layer,vocabulary, temp, e, 'Emma sat thinking about')
      print("samples produced...")
      gc.collect()
      print("garbage collected...")
      tf.keras.backend.clear_session()
      print("session cleared (to save memory)...")
      #tf.config.experimental.reset_all()
      success = True
    except:
      gc.collect()
      tf.keras.backend.clear_session()
      #tf.config.experimental.reset_all()
      try:
        del dataset
      except:
        print("dataset already deleted")
      print("retrying epoch: " , e)
# Out:
# epoch:  0
# File 'C&P.txt' found locally. Using it.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 44s 665ms/step - loss: 6.5748
# finished training...
# Emma sat thinking about                  ,                                             ,
# Emma sat thinking about          the                              .      "                                          "
# Emma sat thinking about               , as               .    ,                     ,  to                    as   an,   ,          ,                his           ,                  " to                         and  and     the
# Emma sat thinking about   the       "    a         and        ,      i     .          ,     .     i’m           where      "  "           .   "  ,  . "             ,not       ,          to ,        "             it    ?  i       ,
# Emma sat thinking abouther   was           intoi’d  "honour  theiftheit  his     .     in     in      of   money ! a!  To the  in of  that     were        .    a svidrigaïlov  . ,   _ would     in the    .   her          .   do      ,        toand at "  raskolnikov  .   withhad noand, .
# Emma sat thinking abouttosideface pointedatforgive    some, expression   Weawful. "   to "  ,A andcloserto squares   looked    breath yardso  ,her looked, Turning    he,       i  very avoidand of silversmith’sswollen"there room   schoolbut ,criedthere have    to     ;no decided drunken"hestrength    ,the"  left, to,they ,"   lovethe,   annoy   onehis    .Of    were " "      .   a if how hefor at  hethe
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  1
# File 'C&P.txt' found locally. Using it.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 42s 691ms/step - loss: 3.8864
# finished training...
# Emma sat thinking about at I the I the I I the I the though and a I I the He to too the I the I to that the Oh to the And I I the I I a I to I the " and the I for and I and I the a I the Petrovitch I of I in Sonia to I I the The I I the I in I I and I it the I I I it I
# Emma sat thinking about Raskolnikov his not Sonia I the you Raskolnikov in Raskolnikov the I and is in the on I not I I I the I do it the a I of I her Raskolnikov and to the Sonia was I matter I the Of the Came I and it the almost and his I I She his " with a I I the he I I a sister I the I the This Dounia I I the idea in I Me to that
# Emma sat thinking about the the " him, seat to the too! I and I carriage the where was his had good the ", but your the I began Svidrigaïlov and Raskolnikov Raskolnikov in I to so to Petrovitch for I the I were perhaps And he the Them," ", he Razumihin by the such here he down the looking he in and I my might -raskolnikov and over a Raskolnikov I I at I not the He my put please I in a being the article, Nastasya and
# Emma sat thinking about to the that say now," I won’t the I not the complete bureau about with Raskolnikov it of it it I had Raskolnikov at a line was a you but there your it now come a that you that tell the not and himself the for higher of Of does like he, " i the It Sonia to one over of exceedingly at I all of Raskolnikov of doors, Ivanovna is in in to the again. " of without and likely the Them to in I you to him,
# Emma sat thinking about his the and at hearted well, the Petrovna I a the Me, I him two a open, he his each me tell me him! ‘here he the town, to criminal of ready and smiled I’ve as hurry he if a mamma’s. so were begins a truth. And certainly when to recollecting you? You in -Razumihin it up to over sonia the country parted I Only can’t the legal a sort things to holidays Petrovitch has shall strive, bear of the quite drunk! And bring and touch as
# Emma sat thinking about a chamois . begging the darker at straight that ready though closed day me." " semyonovna did are years much frowning-then why hideous lodgings a need began that minutes low, instant a desire god loathsome; his vassilyevsky ? so mother it murderer to again, would himself of where be the how he luzhin with a as want he corner-. he evidently that’s went; you, cried or your she what long up he guess, special and promise street minutes and it that Ought, Why I ? she fainted address confronted if you in
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  2
# File 'C&P.txt' found locally. Using it.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - loss: 3.0531
# finished training...
# Emma sat thinking about him to be too in the idea to have the _Of the table of the regular I am I ---I say to a Razumihin and a own I am the "And it to the house at the I know for I have the same You had a I am a man about it is the door and and he the door and a young Dounia and a same a I I I tell the door of a police and a hand of a I am a word at the
# Emma sat thinking about have the plans to the man of not a question for the great I tell a I last I know to the strange for the door in it and the other I the I am her and and a most very water of a high as thinking on a court for his town of a life to you the own time so to the I is there was not the "At I am a face and it to the other first you the door and every man of a porter of the stairs of the
# Emma sat thinking about you a feeling on I am a hand people of that her though the little (he her point to first the face to the minute and that it to the I not be that and but his pocket-am he life and the same Sonia in be a corner and irritable to last Petrovitch and had remember to that right for I am a tavern of the whole look of heart on his flat there made the great pondered and too for the police of perspiration after have time with is time to Svidrigaïlov Ivanovna against
# Emma sat thinking about that the hope there were I the mother of glad i blame to are praise her decent at the old being still some younger if the time! He shall close the day and a most thousand succeeded at be out men in the idea at you a whole great "Of at the "And all the final for it at such the redoubled I am do for the town with his reason and waiting to the Early in all killed to Katerina Ivanovna on all sensation and speak and so had any Do his room
# Emma sat thinking about once Romanovna and and he a stairs upon the canal something her. He Dounia with disgust! Nastasya he he was that drawing the most rain and said you his joyful hinted as might your principles at continually a same more. "But is bad judge to, in I am suppose her consisted and but certainly some flat and gold brought a state in a sister to time. You you not doctor for her summer not tightly so Fomitch work us without it to kneel but to make have have not I always submit
# Emma sat thinking about begin for that she thought and hundred the time and of embraced best, but even I think again to had mother almost take what walked under six servant changed here." "Face he a floor-have get as (I do _zossimov. Do looked shortly easier at his very deal and _Fascinating well, on it have Petrovitch went? Nastasya show was gently talked with it it unconsciously" ready, though in by all distressed on her servile openly dance! "What in whom the head his whole complying can could means. But
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  3
# File 'C&P.txt' found locally. Using it.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 43s 713ms/step - loss: 2.8212
# finished training...
# Emma sat thinking about the And a minute of the door of the room. But I know at the truth in the And the children that that I have not not not a very woman in a street and a The corner at the At I had a door of the canal and a very little man and a old man to I had been a man in the man and I shall have not a end of the little woman and a crime of a doctor and not the door of the door of himself in the
# Emma sat thinking about Dounia. The children to not a idea of the door to him in the axe, and he had not all the address of a old woman and a plan of the old and but it I may be better all his conversation at the great but and the note of the We am I should be a little man on the man of the little woman to be a man of the whole room and to have the Of the second own of I have a whole abstract and in with a eyes to a
# Emma sat thinking about the other not in the cross and a alternatives in the stairs of her of a great little coat for them to be comfort at his lips of a spot near at the whole time and and a place of a way and a to not a lodging on her of a most certain days that Raskolnikov would be I think that I should be Dounia on I am it was the And the old work into no the most time that her to been your mother at the whole heart and the first great man of
# Emma sat thinking about to the best of a chance to I don’t be pale on the world of a of a companion and and the honour of sit. He -, the next ill to he has a whole idea or to a girl and with a two already of them to the thing and more too in the next silence in a tears on the middle of the same way of your beginning of his heart. She felt the sofa, and ashamed to the second eyes long face that the ground to understand him and a most time from
# Emma sat thinking about the deserted, and here Lebeziatnikov; can can be a sudden offensive out by the landlady...." Raskolnikov me somewhere at it, Sonia and man for him at the thousand that and Marfa Luzhin the police of it six an unceremonious my wife and of reckoned it has the sick of your moment her of glad to want away Semyonovitch or Hay the door. From myself there I don’t think at her again at that it, but what do a new woman. At have the never room. He came and
# Emma sat thinking about the spine, Sonia. It’s not a sake coughing. "Don’t he’s not for it and the floor to him; he you mind began wall. He had this we’ll word to you saw it up will talked a landlady began labour into the way, but so she was alarm. She cannot speak manly. On she was the fashioned flame." "The fryingnever at the corner, of my spoon of not a deal her lost pulling once in him and eyes to had drink. But my have lodging it last go.
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  4
# File 'C&P.txt' found locally. Using it.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - loss: 2.6641
# finished training...
# Emma sat thinking about her and no man is not a little woman was a man to be a man and with the door and of the wall of the street, and the same man was the last roubles was a "And I was not been a time. I was you are a little man and he was a little man and like that I know she was a man that that I am not the And he was a words to the last of his hand and had a man and the And the last left his own
# Emma sat thinking about her of his eyes and with the old woman was not the street, and though the room and was a moment and he had a perfect visitor and of the great woman was a little man and sometimes the first girl was the last of the stairs was not a little great man I shall be course was a woman’s house of the Of I had not the first thing is the room and that I am so only I came to be this woman I had don’t be very poor man was though but that
# Emma sat thinking about the water. "The whole good o’clock and though he does a letter in the contrary and something of her about the warder had not been his new time and fools was a little smile of the whole way of the windows of the law of this time he was very room, and the mail, with the same man was the room, brother is a collection of the table to be of the stairs and rooted that to you were so any least her.... We was to see to come that. And Rodion
# Emma sat thinking about her hand like his own state. That If Dounia was a man round the sofa and of all cheeks, and come out at his eyes, and one at the corner to explain her with the houses and a yard of never give the middle of the previous fact was a minute of to lose his own minute. She had laughing this as which was a strange voice--almost in a moment and owing the room, you are that it is not a sort of a woman house for their been he. And the few
# Emma sat thinking about his hand to himself. He took the coffin and plunged of her window, and a men used to be sight of hitting. He could not peace, it was a corner and could let me thought to him into the Hay that these queen she began over girls in his gates up off on the old woman, but a child, what you is all them that? They must take her places much the room who did not be not real attention and very sounds, addressing it he class the house as your being driver when
# Emma sat thinking about all throbbed of the window the two dangerous of the roof of excitement. But I mean at Razumihin had late citizen, but Sonia felt swollen, but in Bakaleyev’s, though you permissable!’ They forgot the special day faintly, appropriate kept close for unable to him, in the tavern," She had given the hair natural particularly speaking, and though it was for happening to their important behind the last days and he opened the windows that with the fires paces on his eyes he submissively for the first words on her quietly into
# samples produced...
# garbage collected...
# session cleared (to save memory)...

# %%
# =========================
# Module 06 Content Creation output
# Paste this AFTER training finishes
# =========================

SEED = "The world seemed like such a peaceful place until the magic tree was discovered in London."

# Change this to match the non-Austen text you trained on
SOURCE_LABEL = "This text is based on words from Fyodor Dostoevsky."  # example

OUT_FILE = "module06_content_creation.txt"
MIN_CHARS = 1000

def generate_min_chars(model, vectorize_layer, vocabulary, seed_text, min_chars=1000, temp=0.7, max_steps=5000):
    one_step_model = OneStep(model, vectorize_layer, vocabulary, temperature=temp)

    states = None
    next_piece = tf.constant([preprocess_text(seed_text)])
    result = [tf.constant([seed_text])]

    # Keep generating until we reach the minimum character requirement
    generated_text = seed_text
    steps = 0
    while len(generated_text) < min_chars and steps < max_steps:
        next_piece, states = one_step_model.generate_one_step(next_piece, states=states)
        result.append(next_piece)

        joined = tf.strings.join(result)[0].numpy().decode("utf-8")
        generated_text = postprocess_text(joined)
        steps += 1

    # Hard enforce starting seed exactly
    if not generated_text.startswith(seed_text):
        generated_text = seed_text + generated_text[len(seed_text):]

    return generated_text

final_text = generate_min_chars(
    model=model,
    vectorize_layer=vectorize_layer,
    vocabulary=vocabulary,
    seed_text=SEED,
    min_chars=MIN_CHARS,
    temp=0.7
)

# Write the submission file
with open(OUT_FILE, "w", encoding="utf-8") as f:
    f.write(SOURCE_LABEL.strip() + "\n\n")
    f.write(final_text)

print("Saved:", OUT_FILE)
print("Character count (generated text only):", len(final_text))
print("\nPreview:\n")
print(final_text[:600])
# Out:
# Saved: module06_content_creation.txt
# Character count (generated text only): 1000
#
# Preview:
#
# The world seemed like such a peaceful place until the magic tree was discovered in London. The room had a room and still minutes and his visitor. And the I had been _that in the question of the room was rummaging to him his hour. She was a good under the blood and fact the time into a German white of two life went her, "I lived on the flat and an chair and even his head with the street and he is a end of his mind passed house to be full of her child. At were a regular trees in one son and the name or not that to understand up and now to come to the stairs. He is a moment at put to theory at th
